# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, AveragePooling2D, Flatten, Dense, MaxPooling2D
from tensorflow.keras.models import Model

print(tf.__version__)
print(np.__version__)
# Out:
# 2.6.0
# 1.21.4

# %%
# function for building resnet Block

# build_residual_block(x, 64, name=f'stage2_{i}', is_50=is_50)

def build_residual_block(x, filters, kernel_size=3, stride=1, conv_shortcut=False, name=None, is_50=False):
    shortcut = x

    if conv_shortcut:
        shortcut = Conv2D(filters, 1, strides=stride, name=name + '_short')(x)
        shortcut = BatchNormalization(name=name + '_bn4')(shortcut)
    
    if is_50:
        x = Conv2D(filters, kernel_size=1, padding='same', strides=stride, name=name + '_conv1')(x)
        x = BatchNormalization(name=name + '_bn1')(x)
        x = Activation('relu', name=name + '_relu1')(x)

    x = Conv2D(filters, kernel_size, padding='same', strides=stride, name=name + '_conv2')(x)
    x = BatchNormalization(name=name + '_bn2')(x)
    x = Activation('relu', name=name + '_relu2')(x)
    
    if is_50:
#         x = Conv2D(filters*4, kernel_size=1, padding='same', name=name + '_conv3')(x)
        x = Conv2D(filters*4, kernel_size=1, name=name + '_conv3')(x)
        x = BatchNormalization(name=name + '_bn3')(x)
    else:
        x = Conv2D(filters, kernel_size, padding='same', name=name + '_conv3')(x)
        x = BatchNormalization(name=name + '_bn3')(x)

    x = Add(name=name + '_add')([x, shortcut])

    x = Activation('relu', name=name + '_relu4')(x)
    
    return x

# %%
# ResNet 모델 자체를 생성하는 함수입니다.
def build_resnet(input_shape, num_classes, is_50):
    inputs = Input(shape=input_shape, name='input_layer')

    x = Conv2D(64, 7, strides=2, padding='same', name='conv2d_15')(inputs)
    x = BatchNormalization(name='batch_normalization_13')(x)
    x = Activation('relu', name='activation_568')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='stage2_0_maxpooling')(x)

    # Stage 2
    for i in range(1, 4):
        x = build_residual_block(x, 64, name=f'stage2_{i}', is_50=is_50)

    # Stage 3
    x = build_residual_block(x, 128, stride=2, conv_shortcut=True, name='stage3_1', is_50=is_50)
    for i in range(2, 5):
        x = build_residual_block(x, 128, name=f'stage3_{i}', is_50=is_50)

    # Stage 4
    x = build_residual_block(x, 256, stride=2, conv_shortcut=True, name='stage4_1', is_50=is_50)
    for i in range(2, 7):
        x = build_residual_block(x, 256, name=f'stage4_{i}', is_50=is_50)

    # Stage 5
    x = build_residual_block(x, 512, stride=2, conv_shortcut=True, name='stage5_1', is_50=is_50)
    for i in range(2, 4):
        x = build_residual_block(x, 512, name=f'stage5_{i}', is_50=is_50)
    
    if is_50:
        x = AveragePooling2D(pool_size=(7, 7), name='avg_pool')(x)
    else:
        x = AveragePooling2D(pool_size=(1, 1), name='avg_pool')(x)
    x = Flatten(name='flatten_11')(x)
    outputs = Dense(num_classes, activation='softmax', name='fc1000')(x)

    model = Model(inputs, outputs, name='resnet34')
    return model

# %%
"""
Total params: 21,315,338
Trainable params: 21,298,314
Non-trainable params: 17,024
"""
input_shape = (32, 32, 3)
num_classes = 10
resnet_34 = build_resnet(input_shape, num_classes, is_50=False)
resnet_34.summary()
# Out:
# Model: "resnet34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_568 (Activation)     (None, 16, 16, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# stage2_0_maxpooling (MaxPooling (None, 7, 7, 64)     0           activation_568[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2 (Conv2D)         (None, 7, 7, 64)     36928       stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn2 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_1_relu2 (Activation)     (None, 7, 7, 64)     0           stage2_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv3 (Conv2D)         (None, 7, 7, 64)     36928       stage2_1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage2_1_add (Add)              (None, 7, 7, 64)     0           stage2_1_bn3[0][0]
#                                                                  stage2_0_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_relu4 (Activation)     (None, 7, 7, 64)     0           stage2_1_add[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2 (Conv2D)         (None, 7, 7, 64)     36928       stage2_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn2 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_2_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_2_relu2 (Activation)     (None, 7, 7, 64)     0           stage2_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv3 (Conv2D)         (None, 7, 7, 64)     36928       stage2_2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn3 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_2_conv3[0][0]
# __________________________________________________________________________________________________
# stage2_2_add (Add)              (None, 7, 7, 64)     0           stage2_2_bn3[0][0]
#                                                                  stage2_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage2_2_relu4 (Activation)     (None, 7, 7, 64)     0           stage2_2_add[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2 (Conv2D)         (None, 7, 7, 64)     36928       stage2_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn2 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_3_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_3_relu2 (Activation)     (None, 7, 7, 64)     0           stage2_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv3 (Conv2D)         (None, 7, 7, 64)     36928       stage2_3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn3 (BatchNormalizatio (None, 7, 7, 64)     256         stage2_3_conv3[0][0]
# __________________________________________________________________________________________________
# stage2_3_add (Add)              (None, 7, 7, 64)     0           stage2_3_bn3[0][0]
#                                                                  stage2_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage2_3_relu4 (Activation)     (None, 7, 7, 64)     0           stage2_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2 (Conv2D)         (None, 4, 4, 128)    73856       stage2_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_1_relu2 (Activation)     (None, 4, 4, 128)    0           stage3_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv3 (Conv2D)         (None, 4, 4, 128)    147584      stage3_1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_1_short (Conv2D)         (None, 4, 4, 128)    8320        stage2_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn4 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_short[0][0]
# __________________________________________________________________________________________________
# stage3_1_add (Add)              (None, 4, 4, 128)    0           stage3_1_bn3[0][0]
#                                                                  stage3_1_bn4[0][0]
# __________________________________________________________________________________________________
# stage3_1_relu4 (Activation)     (None, 4, 4, 128)    0           stage3_1_add[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2 (Conv2D)         (None, 4, 4, 128)    147584      stage3_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_2_relu2 (Activation)     (None, 4, 4, 128)    0           stage3_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv3 (Conv2D)         (None, 4, 4, 128)    147584      stage3_2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_2_conv3[0][0]
# __________________________________________________________________________________________________
# stage3_2_add (Add)              (None, 4, 4, 128)    0           stage3_2_bn3[0][0]
#                                                                  stage3_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_2_relu4 (Activation)     (None, 4, 4, 128)    0           stage3_2_add[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2 (Conv2D)         (None, 4, 4, 128)    147584      stage3_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_3_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_3_relu2 (Activation)     (None, 4, 4, 128)    0           stage3_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv3 (Conv2D)         (None, 4, 4, 128)    147584      stage3_3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_3_conv3[0][0]
# __________________________________________________________________________________________________
# stage3_3_add (Add)              (None, 4, 4, 128)    0           stage3_3_bn3[0][0]
#                                                                  stage3_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_3_relu4 (Activation)     (None, 4, 4, 128)    0           stage3_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2 (Conv2D)         (None, 4, 4, 128)    147584      stage3_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_4_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_4_relu2 (Activation)     (None, 4, 4, 128)    0           stage3_4_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv3 (Conv2D)         (None, 4, 4, 128)    147584      stage3_4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_4_conv3[0][0]
# __________________________________________________________________________________________________
# stage3_4_add (Add)              (None, 4, 4, 128)    0           stage3_4_bn3[0][0]
#                                                                  stage3_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage3_4_relu4 (Activation)     (None, 4, 4, 128)    0           stage3_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2 (Conv2D)         (None, 2, 2, 256)    295168      stage3_4_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_1_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_1_short (Conv2D)         (None, 2, 2, 256)    33024       stage3_4_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn4 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_short[0][0]
# __________________________________________________________________________________________________
# stage4_1_add (Add)              (None, 2, 2, 256)    0           stage4_1_bn3[0][0]
#                                                                  stage4_1_bn4[0][0]
# __________________________________________________________________________________________________
# stage4_1_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_1_add[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2 (Conv2D)         (None, 2, 2, 256)    590080      stage4_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_2_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_2_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_2_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_2_add (Add)              (None, 2, 2, 256)    0           stage4_2_bn3[0][0]
#                                                                  stage4_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_2_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_2_add[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2 (Conv2D)         (None, 2, 2, 256)    590080      stage4_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_3_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_3_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_3_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_3_add (Add)              (None, 2, 2, 256)    0           stage4_3_bn3[0][0]
#                                                                  stage4_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_3_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_3_add[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2 (Conv2D)         (None, 2, 2, 256)    590080      stage4_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_4_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_4_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_4_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_4_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_4_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_4_add (Add)              (None, 2, 2, 256)    0           stage4_4_bn3[0][0]
#                                                                  stage4_3_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_4_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2 (Conv2D)         (None, 2, 2, 256)    590080      stage4_4_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_5_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_5_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_5_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_5_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_5_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_5_add (Add)              (None, 2, 2, 256)    0           stage4_5_bn3[0][0]
#                                                                  stage4_4_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_5_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_5_add[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2 (Conv2D)         (None, 2, 2, 256)    590080      stage4_5_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_6_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_6_relu2 (Activation)     (None, 2, 2, 256)    0           stage4_6_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv3 (Conv2D)         (None, 2, 2, 256)    590080      stage4_6_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_6_conv3[0][0]
# __________________________________________________________________________________________________
# stage4_6_add (Add)              (None, 2, 2, 256)    0           stage4_6_bn3[0][0]
#                                                                  stage4_5_relu4[0][0]
# __________________________________________________________________________________________________
# stage4_6_relu4 (Activation)     (None, 2, 2, 256)    0           stage4_6_add[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2 (Conv2D)         (None, 1, 1, 512)    1180160     stage4_6_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2[0][0]
# __________________________________________________________________________________________________
# stage5_1_relu2 (Activation)     (None, 1, 1, 512)    0           stage5_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv3 (Conv2D)         (None, 1, 1, 512)    2359808     stage5_1_relu2[0][0]
# __________________________________________________________________________________________________
# stage5_1_short (Conv2D)         (None, 1, 1, 512)    131584      stage4_6_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv3[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn4 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_short[0][0]
# __________________________________________________________________________________________________
# stage5_1_add (Add)              (None, 1, 1, 512)    0           stage5_1_bn3[0][0]
#                                                                  stage5_1_bn4[0][0]
# __________________________________________________________________________________________________
# stage5_1_relu4 (Activation)     (None, 1, 1, 512)    0           stage5_1_add[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     stage5_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_2_conv2[0][0]
# __________________________________________________________________________________________________
# stage5_2_relu2 (Activation)     (None, 1, 1, 512)    0           stage5_2_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv3 (Conv2D)         (None, 1, 1, 512)    2359808     stage5_2_relu2[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_2_conv3[0][0]
# __________________________________________________________________________________________________
# stage5_2_add (Add)              (None, 1, 1, 512)    0           stage5_2_bn3[0][0]
#                                                                  stage5_1_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_2_relu4 (Activation)     (None, 1, 1, 512)    0           stage5_2_add[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2 (Conv2D)         (None, 1, 1, 512)    2359808     stage5_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_3_conv2[0][0]
# __________________________________________________________________________________________________
# stage5_3_relu2 (Activation)     (None, 1, 1, 512)    0           stage5_3_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv3 (Conv2D)         (None, 1, 1, 512)    2359808     stage5_3_relu2[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_3_conv3[0][0]
# __________________________________________________________________________________________________
# stage5_3_add (Add)              (None, 1, 1, 512)    0           stage5_3_bn3[0][0]
#                                                                  stage5_2_relu4[0][0]
# __________________________________________________________________________________________________
# stage5_3_relu4 (Activation)     (None, 1, 1, 512)    0           stage5_3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 512)    0           stage5_3_relu4[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 512)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           5130        flatten_11[0][0]
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %%
input_shape = (32, 32, 3)
num_classes = 10
resnet_50 = build_resnet(input_shape, num_classes, is_50=True)
resnet_50.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32/2446115072.py in <module>
#       1 input_shape = (32, 32, 3)
#       2 num_classes = 10
# ----> 3 resnet_50 = build_resnet(input_shape, num_classes, is_50=True)
#       4 resnet_50.summary()
#
# /tmp/ipykernel_32/284438757.py in build_resnet(input_shape, num_classes, is_50)
#      10     # Stage 2
#      11     for i in range(1, 4):
# ---> 12         x = build_residual_block(x, 64, name=f'stage2_{i}', is_50=is_50)
#      13
#      14     # Stage 3
#
# /tmp/ipykernel_32/4250506245.py in build_residual_block(x, filters, kernel_size, stride, conv_shortcut, name, is_50)
#      27     x = BatchNormalization(name=name + '_bn3')(x)
#      28
# ---> 29     x = Add(name=name + '_add')([x, shortcut])
#      30     x = Activation('relu', name=name + '_relu4')(x)
#      31
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     974     # >> model = tf.keras.Model(inputs, outputs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 976       return self._functional_construction_call(inputs, args, kwargs,
#     977                                                 input_list)
#     978
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1112         layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1113       # Check input assumptions set after layer building, e.g. input shape.
# -> 1114       outputs = self._keras_tensor_symbolic_call(
#    1115           inputs, input_masks, args, kwargs)
#    1116
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     884           # overridden).
#     885           # TODO(kaftan): do we maybe_build here, or have we already done it?
# --> 886           self._maybe_build(inputs)
#     887           inputs = self._maybe_cast_inputs(inputs)
#     888           outputs = call_fn(inputs, *args, **kwargs)
#
# /opt/conda/lib/python3.9/site-packages/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2657         # operations.
#    2658         with tf_utils.maybe_init_scope(self):
# -> 2659           self.build(input_shapes)  # pylint:disable=not-callable
#    2660       # We must set also ensure that the layer is marked as built, and the build
#    2661       # shape is stored since user defined build functions may not be calling
#
# /opt/conda/lib/python3.9/site-packages/keras/utils/tf_utils.py in wrapper(instance, input_shape)
#     257     if input_shape is not None:
#     258       input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 259     output_shape = fn(instance, input_shape)
#     260     # Return shapes from `fn` as TensorShapes.
#     261     if output_shape is not None:
#
# /opt/conda/lib/python3.9/site-packages/keras/layers/merge.py in build(self, input_shape)
#     105       else:
#     106         shape = input_shape[i][1:]
# --> 107       output_shape = self._compute_elemwise_op_output_shape(output_shape, shape)
#     108     # If the inputs have different ranks, we have to reshape them
#     109     # to make them broadcastable.
#
# /opt/conda/lib/python3.9/site-packages/keras/layers/merge.py in _compute_elemwise_op_output_shape(self, shape1, shape2)
#      76       else:
#      77         if i != j:
# ---> 78           raise ValueError(
#      79               'Operands could not be broadcast '
#      80               'together with shapes ' + str(shape1) + ' ' + str(shape2))
#
# ValueError: Operands could not be broadcast together with shapes (7, 7, 256) (7, 7, 64)

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model


def build_residual_block(input_layer, filters, kernel_size, stage, block):
    conv_name_base = f'res{stage}_{block}_branch'
    bn_name_base = f'bn{stage}_{block}_branch'

    x = Conv2D(filters=filters, kernel_size=kernel_size, padding='same', name=conv_name_base + '_2a')(input_layer)
    x = BatchNormalization(axis=3, name=bn_name_base + '_2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=filters, kernel_size=kernel_size, padding='same', name=conv_name_base + '_2b')(x)
    x = BatchNormalization(axis=3, name=bn_name_base + '_2b')(x)

    shortcut = Conv2D(filters=filters, kernel_size=(1, 1), padding='valid', name=conv_name_base + '_1')(input_layer)
    shortcut = BatchNormalization(axis=3, name=bn_name_base + '_1')(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x


def build_resnet(input_shape=(32, 32, 3), is_50=True, num_classes=10):
    input_layer = Input(shape=input_shape, name='input_layer')

    x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), name='conv1_conv')(input_layer)
    x = BatchNormalization(axis=3, name='conv1_bn')(x)
    x = Activation('relu', name='conv1_relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='pool1_pool')(x)

    # Choose between ResNet50 or ResNet34 based on is_50 flag
    if is_50:
        x = build_residual_block(x, filters=64, kernel_size=3, stage=2, block='a')
        x = build_residual_block(x, filters=64, kernel_size=3, stage=2, block='b')
        x = build_residual_block(x, filters=64, kernel_size=3, stage=2, block='c')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='a')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='b')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='c')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='d')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='a')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='b')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='c')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='d')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='e')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='f')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='a')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='b')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='c')
    else:
        x = build_residual_block(x, filters=64, kernel_size=3, stage=2, block='a')
        x = build_residual_block(x, filters=64, kernel_size=3, stage=2, block='b')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='a')
        x = build_residual_block(x, filters=128, kernel_size=3, stage=3, block='b')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='a')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='b')
        x = build_residual_block(x, filters=256, kernel_size=3, stage=4, block='c')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='a')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='b')
        x = build_residual_block(x, filters=512, kernel_size=3, stage=5, block='c')

    x = AveragePooling2D(pool_size=(2, 2), padding='same', name='avg_pool')(x)
    x = Flatten()(x)
    x = Dense(num_classes, activation='softmax', name='fc')(x)

    model = Model(inputs=input_layer, outputs=x, name='ResNet50' if is_50 else 'ResNet34')

    return model

# %%
# Test ResNet34
resnet_34 = build_resnet(input_shape=(32, 32, 3), is_50=False)
resnet_34.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_2a (Conv2D)       (None, 8, 8, 64)     36928       pool1_pool[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_2a (BatchNormaliza (None, 8, 8, 64)     256         res2_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 64)     0           bn2_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_2b (Conv2D)       (None, 8, 8, 64)     36928       activation_48[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_1 (Conv2D)        (None, 8, 8, 64)     4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_2b (BatchNormaliza (None, 8, 8, 64)     256         res2_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_1 (BatchNormalizat (None, 8, 8, 64)     256         res2_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 8, 8, 64)     0           bn2_a_branch_2b[0][0]
#                                                                  bn2_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 64)     0           add_24[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_2a (Conv2D)       (None, 8, 8, 64)     36928       activation_49[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_2a (BatchNormaliza (None, 8, 8, 64)     256         res2_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 64)     0           bn2_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_2b (Conv2D)       (None, 8, 8, 64)     36928       activation_50[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_1 (Conv2D)        (None, 8, 8, 64)     4160        activation_49[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_2b (BatchNormaliza (None, 8, 8, 64)     256         res2_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_1 (BatchNormalizat (None, 8, 8, 64)     256         res2_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           bn2_b_branch_2b[0][0]
#                                                                  bn2_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_2a (Conv2D)       (None, 8, 8, 128)    73856       activation_51[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 128)    0           bn3_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_52[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_1 (Conv2D)        (None, 8, 8, 128)    8320        activation_51[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 128)    0           bn3_a_branch_2b[0][0]
#                                                                  bn3_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 128)    0           add_26[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_2a (Conv2D)       (None, 8, 8, 128)    147584      activation_53[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 128)    0           bn3_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_54[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_1 (Conv2D)        (None, 8, 8, 128)    16512       activation_53[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 128)    0           bn3_b_branch_2b[0][0]
#                                                                  bn3_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 128)    0           add_27[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_2a (Conv2D)       (None, 8, 8, 256)    295168      activation_55[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 256)    0           bn4_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_56[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_1 (Conv2D)        (None, 8, 8, 256)    33024       activation_55[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 8, 8, 256)    0           bn4_a_branch_2b[0][0]
#                                                                  bn4_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 256)    0           add_28[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_57[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8, 8, 256)    0           bn4_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_58[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_57[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 8, 8, 256)    0           bn4_b_branch_2b[0][0]
#                                                                  bn4_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 8, 8, 256)    0           add_29[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_59[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8, 8, 256)    0           bn4_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_60[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_59[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 8, 8, 256)    0           bn4_c_branch_2b[0][0]
#                                                                  bn4_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 8, 8, 256)    0           add_30[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_2a (Conv2D)       (None, 8, 8, 512)    1180160     activation_61[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 8, 8, 512)    0           bn5_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_62[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_1 (Conv2D)        (None, 8, 8, 512)    131584      activation_61[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 8, 8, 512)    0           bn5_a_branch_2b[0][0]
#                                                                  bn5_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 8, 8, 512)    0           add_31[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_2a (Conv2D)       (None, 8, 8, 512)    2359808     activation_63[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 8, 8, 512)    0           bn5_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_64[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_1 (Conv2D)        (None, 8, 8, 512)    262656      activation_63[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 8, 8, 512)    0           bn5_b_branch_2b[0][0]
#                                                                  bn5_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 8, 8, 512)    0           add_32[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_2a (Conv2D)       (None, 8, 8, 512)    2359808     activation_65[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 8, 8, 512)    0           bn5_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_66[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_1 (Conv2D)        (None, 8, 8, 512)    262656      activation_65[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 8, 8, 512)    0           bn5_c_branch_2b[0][0]
#                                                                  bn5_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 8, 8, 512)    0           add_33[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 4, 4, 512)    0           activation_67[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 10)           81930       flatten_1[0][0]
# ==================================================================================================
# Total params: 17,867,658
# Trainable params: 17,851,402
# Non-trainable params: 16,256
# __________________________________________________________________________________________________

# %%
# Test ResNet50
resnet_50 = build_resnet(input_shape=(32, 32, 3), is_50=True)
resnet_50.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_2a (Conv2D)       (None, 8, 8, 64)     36928       pool1_pool[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_2a (BatchNormaliza (None, 8, 8, 64)     256         res2_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 8, 8, 64)     0           bn2_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_2b (Conv2D)       (None, 8, 8, 64)     36928       activation_68[0][0]
# __________________________________________________________________________________________________
# res2_a_branch_1 (Conv2D)        (None, 8, 8, 64)     4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_2b (BatchNormaliza (None, 8, 8, 64)     256         res2_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn2_a_branch_1 (BatchNormalizat (None, 8, 8, 64)     256         res2_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 64)     0           bn2_a_branch_2b[0][0]
#                                                                  bn2_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 8, 8, 64)     0           add_34[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_2a (Conv2D)       (None, 8, 8, 64)     36928       activation_69[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_2a (BatchNormaliza (None, 8, 8, 64)     256         res2_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 8, 8, 64)     0           bn2_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_2b (Conv2D)       (None, 8, 8, 64)     36928       activation_70[0][0]
# __________________________________________________________________________________________________
# res2_b_branch_1 (Conv2D)        (None, 8, 8, 64)     4160        activation_69[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_2b (BatchNormaliza (None, 8, 8, 64)     256         res2_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn2_b_branch_1 (BatchNormalizat (None, 8, 8, 64)     256         res2_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 64)     0           bn2_b_branch_2b[0][0]
#                                                                  bn2_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 64)     0           add_35[0][0]
# __________________________________________________________________________________________________
# res2_c_branch_2a (Conv2D)       (None, 8, 8, 64)     36928       activation_71[0][0]
# __________________________________________________________________________________________________
# bn2_c_branch_2a (BatchNormaliza (None, 8, 8, 64)     256         res2_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 8, 8, 64)     0           bn2_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res2_c_branch_2b (Conv2D)       (None, 8, 8, 64)     36928       activation_72[0][0]
# __________________________________________________________________________________________________
# res2_c_branch_1 (Conv2D)        (None, 8, 8, 64)     4160        activation_71[0][0]
# __________________________________________________________________________________________________
# bn2_c_branch_2b (BatchNormaliza (None, 8, 8, 64)     256         res2_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn2_c_branch_1 (BatchNormalizat (None, 8, 8, 64)     256         res2_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 64)     0           bn2_c_branch_2b[0][0]
#                                                                  bn2_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 8, 8, 64)     0           add_36[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_2a (Conv2D)       (None, 8, 8, 128)    73856       activation_73[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 8, 8, 128)    0           bn3_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_74[0][0]
# __________________________________________________________________________________________________
# res3_a_branch_1 (Conv2D)        (None, 8, 8, 128)    8320        activation_73[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_a_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 8, 8, 128)    0           bn3_a_branch_2b[0][0]
#                                                                  bn3_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 128)    0           add_37[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_2a (Conv2D)       (None, 8, 8, 128)    147584      activation_75[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 128)    0           bn3_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_76[0][0]
# __________________________________________________________________________________________________
# res3_b_branch_1 (Conv2D)        (None, 8, 8, 128)    16512       activation_75[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_b_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 8, 8, 128)    0           bn3_b_branch_2b[0][0]
#                                                                  bn3_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 128)    0           add_38[0][0]
# __________________________________________________________________________________________________
# res3_c_branch_2a (Conv2D)       (None, 8, 8, 128)    147584      activation_77[0][0]
# __________________________________________________________________________________________________
# bn3_c_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 128)    0           bn3_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_c_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_78[0][0]
# __________________________________________________________________________________________________
# res3_c_branch_1 (Conv2D)        (None, 8, 8, 128)    16512       activation_77[0][0]
# __________________________________________________________________________________________________
# bn3_c_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_c_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 8, 8, 128)    0           bn3_c_branch_2b[0][0]
#                                                                  bn3_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 128)    0           add_39[0][0]
# __________________________________________________________________________________________________
# res3_d_branch_2a (Conv2D)       (None, 8, 8, 128)    147584      activation_79[0][0]
# __________________________________________________________________________________________________
# bn3_d_branch_2a (BatchNormaliza (None, 8, 8, 128)    512         res3_d_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 128)    0           bn3_d_branch_2a[0][0]
# __________________________________________________________________________________________________
# res3_d_branch_2b (Conv2D)       (None, 8, 8, 128)    147584      activation_80[0][0]
# __________________________________________________________________________________________________
# res3_d_branch_1 (Conv2D)        (None, 8, 8, 128)    16512       activation_79[0][0]
# __________________________________________________________________________________________________
# bn3_d_branch_2b (BatchNormaliza (None, 8, 8, 128)    512         res3_d_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn3_d_branch_1 (BatchNormalizat (None, 8, 8, 128)    512         res3_d_branch_1[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 8, 8, 128)    0           bn3_d_branch_2b[0][0]
#                                                                  bn3_d_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 128)    0           add_40[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_2a (Conv2D)       (None, 8, 8, 256)    295168      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 256)    0           bn4_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_82[0][0]
# __________________________________________________________________________________________________
# res4_a_branch_1 (Conv2D)        (None, 8, 8, 256)    33024       activation_81[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_a_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 8, 8, 256)    0           bn4_a_branch_2b[0][0]
#                                                                  bn4_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 256)    0           add_41[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 256)    0           bn4_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_84[0][0]
# __________________________________________________________________________________________________
# res4_b_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_83[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_b_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 8, 8, 256)    0           bn4_b_branch_2b[0][0]
#                                                                  bn4_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 256)    0           add_42[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 256)    0           bn4_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_86[0][0]
# __________________________________________________________________________________________________
# res4_c_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_85[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_c_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 8, 8, 256)    0           bn4_c_branch_2b[0][0]
#                                                                  bn4_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 256)    0           add_43[0][0]
# __________________________________________________________________________________________________
# res4_d_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4_d_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_d_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 256)    0           bn4_d_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_d_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_88[0][0]
# __________________________________________________________________________________________________
# res4_d_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_87[0][0]
# __________________________________________________________________________________________________
# bn4_d_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_d_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_d_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_d_branch_1[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 8, 8, 256)    0           bn4_d_branch_2b[0][0]
#                                                                  bn4_d_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 256)    0           add_44[0][0]
# __________________________________________________________________________________________________
# res4_e_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_89[0][0]
# __________________________________________________________________________________________________
# bn4_e_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_e_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 256)    0           bn4_e_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_e_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_90[0][0]
# __________________________________________________________________________________________________
# res4_e_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_89[0][0]
# __________________________________________________________________________________________________
# bn4_e_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_e_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_e_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_e_branch_1[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 8, 8, 256)    0           bn4_e_branch_2b[0][0]
#                                                                  bn4_e_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 256)    0           add_45[0][0]
# __________________________________________________________________________________________________
# res4_f_branch_2a (Conv2D)       (None, 8, 8, 256)    590080      activation_91[0][0]
# __________________________________________________________________________________________________
# bn4_f_branch_2a (BatchNormaliza (None, 8, 8, 256)    1024        res4_f_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 256)    0           bn4_f_branch_2a[0][0]
# __________________________________________________________________________________________________
# res4_f_branch_2b (Conv2D)       (None, 8, 8, 256)    590080      activation_92[0][0]
# __________________________________________________________________________________________________
# res4_f_branch_1 (Conv2D)        (None, 8, 8, 256)    65792       activation_91[0][0]
# __________________________________________________________________________________________________
# bn4_f_branch_2b (BatchNormaliza (None, 8, 8, 256)    1024        res4_f_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn4_f_branch_1 (BatchNormalizat (None, 8, 8, 256)    1024        res4_f_branch_1[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 8, 8, 256)    0           bn4_f_branch_2b[0][0]
#                                                                  bn4_f_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 256)    0           add_46[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_2a (Conv2D)       (None, 8, 8, 512)    1180160     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 8, 8, 512)    0           bn5_a_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_94[0][0]
# __________________________________________________________________________________________________
# res5_a_branch_1 (Conv2D)        (None, 8, 8, 512)    131584      activation_93[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_a_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_a_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_a_branch_1[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 8, 8, 512)    0           bn5_a_branch_2b[0][0]
#                                                                  bn5_a_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 8, 8, 512)    0           add_47[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_2a (Conv2D)       (None, 8, 8, 512)    2359808     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 8, 8, 512)    0           bn5_b_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# res5_b_branch_1 (Conv2D)        (None, 8, 8, 512)    262656      activation_95[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_b_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_b_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_b_branch_1[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 8, 8, 512)    0           bn5_b_branch_2b[0][0]
#                                                                  bn5_b_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 8, 8, 512)    0           add_48[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_2a (Conv2D)       (None, 8, 8, 512)    2359808     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_2a (BatchNormaliza (None, 8, 8, 512)    2048        res5_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 8, 8, 512)    0           bn5_c_branch_2a[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_2b (Conv2D)       (None, 8, 8, 512)    2359808     activation_98[0][0]
# __________________________________________________________________________________________________
# res5_c_branch_1 (Conv2D)        (None, 8, 8, 512)    262656      activation_97[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_2b (BatchNormaliza (None, 8, 8, 512)    2048        res5_c_branch_2b[0][0]
# __________________________________________________________________________________________________
# bn5_c_branch_1 (BatchNormalizat (None, 8, 8, 512)    2048        res5_c_branch_1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 8, 8, 512)    0           bn5_c_branch_2b[0][0]
#                                                                  bn5_c_branch_1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 8, 8, 512)    0           add_49[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 4, 4, 512)    0           activation_99[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 8192)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 10)           81930       flatten_2[0][0]
# ==================================================================================================
# Total params: 22,319,946
# Trainable params: 22,297,162
# Non-trainable params: 22,784
# __________________________________________________________________________________________________

# %%
# is_50 : True --> resnet_50
# is_plain :True --> no skip connection    
def build_resnet_block(input_layer, num_cnn=3, channel=64, block_num=1,is_50 = False,is_plain = False):
    # 입력 레이어
    x = input_layer
    if not is_50:
    # CNN 레이어
        for cnn_num in range(num_cnn):
            identity = x
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_conv{cnn_num}'
            )(x)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Conv2D(
                filters=channel,
                kernel_size=(3,3),
                activation='relu',
                kernel_initializer='he_normal',
                padding='same',
                name=f'block{block_num}_1_conv{cnn_num}'
            )(x)
            if not is_plain:
                identity_channel = identity.shape.as_list()[-1]    

                if identity_channel != channel:
                    identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
                # skip connection
                x = keras.layers.Add()([x,identity])   
            else:
                pass
    else :
        identity = x
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_conv{cnn_num}'
        )(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Conv2D(
            filters=channel,
            kernel_size=(3,3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_1_conv{cnn_num}'
        )(x)
        x = keras.layers.Conv2D(
            filters=channel * 4,
            kernel_size=(1,1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name=f'block{block_num}_2_conv{cnn_num}'
        )(x)
        if not is_plain:
            identity_channel = identity.shape.as_list()[-1]    

            if identity_channel != channel:
                identity = keras.layers.Conv2D(channel, kernel_size=(1, 1), strides=(1, 1), padding="same")(identity)  
            # skip connection
            x = keras.layers.Add()([x,identity])   
        else:
            pass
    #     Max Pooling 레이어
    # 마지막 블록 뒤에는 pooling을 하지 않음
    if identity.shape[1] != 1:        
        x = keras.layers.MaxPooling2D(
            pool_size=(2, 2),
            strides=2,
            name=f'block{block_num}_pooling'
        )(x)

    return x
