# %%
# !pip install keras-tuner -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 3.2 MB/s eta 0:00:00

# %% [markdown]
# # keras 튜너

# %% [markdown]
# ## keras 튜너 빌드용

# %%
from tensorflow import keras
from tensorflow.keras import layers

def build_model(hp):
    # hp 객체에서 하이퍼 파라미터 값을 샘플링
    # 샘플링한 값은("units")는 파이썬 상수임
    units = hp.Int(name="units", min_value=16, max_value=64, step=16)
    model = keras.Sequential([
        layers.Dense(units, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    # 여러 종류의 하이퍼파라미터를 제공
    # Int, Float, Boolean, Choice등이 있다
    optimizer = hp.Choice(name="optimizer", values=["rmsprop", "adam"])
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])
    return model

# %%
# keras tuner의 HyperModel을 상속받은 튜너를

import keras_tuner as kt

class SimpleMLP(kt.HyperModel):
    def __init__(self, num_classes):
        self.num_classes = num_classes

    def build(self, hp):
        units = hp.Int(name="units", min_value=16, max_value=64, step=16)
        model = keras.Sequential([
            layers.Dense(units, activation="relu"),
            layers.Dense(self.num_classes, activation="softmax")
        ])
        optimizer = hp.Choice(name="optimizer", values=["rmsprop", "adam"])
        model.compile(
            optimizer=optimizer,
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"])
        return model

hypermodel = SimpleMLP(num_classes=10)

# %% [markdown]
# ## [케라스 튜너 종류](https://keras.io/api/keras_tuner/tuners/)

# %%
# KerasTuner의 내장 튜너
# BayesianOptimization 튜너는 이전 선택ㄱ의 결과를 바탕으로 최상의 하이퍼파라미터 값을 스마트하게 예측하게해줌
tuner = kt.BayesianOptimization(
    build_model,
    objective="val_accuracy",
    # 코랩에서 정상 실행만 확인하기 위해 최대 탐색 횟수를 100에서 10으로 줄입니다
    max_trials=10, # 100
    executions_per_trial=2,
    directory="mnist_kt_test",
    overwrite=True,
)

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 64, 'step': 16, 'sampling': 'linear'}
# optimizer (Choice)
# {'default': 'rmsprop', 'conditions': [], 'values': ['rmsprop', 'adam'], 'ordered': False}

# %% [markdown]
# ## Mnist 데이터셋 load 및 BayesianOptimization 으로 하이퍼파라미터 찾기

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape((-1, 28 * 28)).astype("float32") / 255
x_test = x_test.reshape((-1, 28 * 28)).astype("float32") / 255
x_train_full = x_train[:]
y_train_full = y_train[:]

num_val_samples = 10000
x_train, x_val = x_train[:-num_val_samples], x_train[-num_val_samples:]
y_train, y_val = y_train[:-num_val_samples], y_train[-num_val_samples:]

callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=5),
]

tuner.search(
    x_train, y_train,
    batch_size=128,
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Trial 10 Complete [00h 00m 53s]
# val_accuracy: 0.9748499989509583
#
# Best val_accuracy So Far: 0.9760499894618988
# Total elapsed time: 00h 11m 38s

# %%
# best 파라미터 확인
top_n = 4
best_hps = tuner.get_best_hyperparameters(top_n)

# %%
print(best_hps)
print("-"*30)
print(best_hps[0].Choice(name="optimizer", values=["rmsprop", "adam"]))

# best 파라미터로 model build
model = build_model(best_hps[0])
# Out:
# [<keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ee9944199c0>, <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ee99c119240>, <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ee9946e7f10>, <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7ee994f412d0>]
# ------------------------------
# rmsprop

# %%
from keras_tuner.engine.hyperparameters import Int
print(1)
print(best_hps[0]._conditions_are_active(Int(name="units", min_value=0, max_value=1).conditions))
print("-"*30)

print(2)
print(best_hps[0]._hps)
print("-"*30)

print(3)
print(best_hps[0]._exists('units', []))
print("-"*30)

print(4)
print(best_hps[0].values)
print("-"*30)

print(5)
print(best_hps[0].Int(name="units", min_value=0, max_value=1))
print("-"*30)

print(6)
model.get_config()
# Out:
# 1
# True
# ------------------------------
# 2
# defaultdict(<class 'list'>, {'units': [Int(name: 'units', min_value: 16, max_value: 64, step: 16, sampling: linear, default: 16)], 'optimizer': [Choice(name: 'optimizer', values: ['rmsprop', 'adam'], ordered: False, default: rmsprop)]})
# ------------------------------
# 3
# True
# ------------------------------
# 4
# {'units': 64, 'optimizer': 'rmsprop'}
# ------------------------------
# 5
# 64
# ------------------------------
# 6
# {'name': 'sequential_1',
#  'layers': [{'module': 'keras.layers',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 64,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'module': 'keras.initializers',
#      'class_name': 'GlorotUniform',
#      'config': {'seed': None},
#      'registered_name': None},
#     'bias_initializer': {'module': 'keras.initializers',
#      'class_name': 'Zeros',
#      'config': {},
#      'registered_name': None},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'registered_name': None},
#   {'module': 'keras.layers',
#    'class_name': 'Dense',
#    'config': {'name': 'dense_3',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 10,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'module': 'keras.initializers',
#      'class_name': 'GlorotUniform',
#      'config': {'seed': None},
#      'registered_name': None},
#     'bias_initializer': {'module': 'keras.initializers',
#      'class_name': 'Zeros',
#      'config': {},
#      'registered_name': None},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'registered_name': None}]}

# %%
# 최상의 epoch 횟수 찾기
def get_best_epoch(hp):
    model = build_model(hp)
    callbacks=[
        keras.callbacks.EarlyStopping(
            monitor="val_loss", mode="min", patience=10)
    ]
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=100,
        batch_size=128,
        callbacks=callbacks)
    val_loss_per_epoch = history.history["val_loss"]
    best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
    print(f"Best epoch: {best_epoch}")
    return best_epoch

# %%
# 위 훈련 데이터셋으로 찾은 최상의 epoch보다 20%만큼 더 많이 epoch을 지정하여 다시 훈련
def get_best_trained_model(hp):
    best_epoch = get_best_epoch(hp)
    model.fit(
        x_train_full, y_train_full,
        batch_size=128, epochs=int(best_epoch * 1.2))
    return model

# %%
# 모델 훈련 및 평가
best_models = []
for hp in best_hps:
    model = get_best_trained_model(hp)
    model.evaluate(x_test, y_test)
    best_models.append(model)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.4213 - accuracy: 0.8863 - val_loss: 0.2259 - val_accuracy: 0.9366
# Epoch 2/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.2183 - accuracy: 0.9378 - val_loss: 0.1820 - val_accuracy: 0.9509
# Epoch 3/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1711 - accuracy: 0.9516 - val_loss: 0.1537 - val_accuracy: 0.9571
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1412 - accuracy: 0.9603 - val_loss: 0.1345 - val_accuracy: 0.9638
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1194 - accuracy: 0.9664 - val_loss: 0.1239 - val_accuracy: 0.9652
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1035 - accuracy: 0.9709 - val_loss: 0.1159 - val_accuracy: 0.9665
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0911 - accuracy: 0.9749 - val_loss: 0.1124 - val_accuracy: 0.9690
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0815 - accuracy: 0.9774 - val_loss: 0.1036 - val_accuracy: 0.9702
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0735 - accuracy: 0.9789 - val_loss: 0.1061 - val_accuracy: 0.9713
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0671 - accuracy: 0.9808 - val_loss: 0.0972 - val_accuracy: 0.9728
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0609 - accuracy: 0.9826 - val_loss: 0.1007 - val_accuracy: 0.9712
# Epoch 12/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0550 - accuracy: 0.9847 - val_loss: 0.0981 - val_accuracy: 0.9717
# Epoch 13/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0511 - accuracy: 0.9853 - val_loss: 0.0953 - val_accuracy: 0.9733
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0466 - accuracy: 0.9872 - val_loss: 0.1007 - val_accuracy: 0.9727
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0435 - accuracy: 0.9879 - val_loss: 0.0971 - val_accuracy: 0.9735
# Epoch 16/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0392 - accuracy: 0.9890 - val_loss: 0.0976 - val_accuracy: 0.9737
# Epoch 17/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9894 - val_loss: 0.1007 - val_accuracy: 0.9727
# Epoch 18/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0337 - accuracy: 0.9909 - val_loss: 0.0978 - val_accuracy: 0.9739
# Epoch 19/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0311 - accuracy: 0.9915 - val_loss: 0.0986 - val_accuracy: 0.9739
# Epoch 20/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0294 - accuracy: 0.9922 - val_loss: 0.0973 - val_accuracy: 0.9745
# Epoch 21/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0266 - accuracy: 0.9933 - val_loss: 0.1023 - val_accuracy: 0.9727
# Epoch 22/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 0.0939 - val_accuracy: 0.9743
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0229 - accuracy: 0.9939 - val_loss: 0.1028 - val_accuracy: 0.9747
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.1038 - val_accuracy: 0.9755
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0198 - accuracy: 0.9949 - val_loss: 0.0991 - val_accuracy: 0.9756
# Epoch 26/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 0.1089 - val_accuracy: 0.9721
# Epoch 27/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.1105 - val_accuracy: 0.9726
# Epoch 28/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0156 - accuracy: 0.9963 - val_loss: 0.1100 - val_accuracy: 0.9741
# Epoch 29/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.1084 - val_accuracy: 0.9725
# Epoch 30/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9970 - val_loss: 0.1043 - val_accuracy: 0.9749
# Epoch 31/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0121 - accuracy: 0.9973 - val_loss: 0.1061 - val_accuracy: 0.9743
# Epoch 32/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.1186 - val_accuracy: 0.9728
# Best epoch: 22
# Epoch 1/26
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3904 - accuracy: 0.8949
# Epoch 2/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2011 - accuracy: 0.9416
# Epoch 3/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1559 - accuracy: 0.9553
# Epoch 4/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1267 - accuracy: 0.9629
# Epoch 5/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1068 - accuracy: 0.9689
# Epoch 6/26
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0922 - accuracy: 0.9732
# Epoch 7/26
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0805 - accuracy: 0.9764
# Epoch 8/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0720 - accuracy: 0.9794
# Epoch 9/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0647 - accuracy: 0.9814
# Epoch 10/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0579 - accuracy: 0.9833
# Epoch 11/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0531 - accuracy: 0.9845
# Epoch 12/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9858
# Epoch 13/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0443 - accuracy: 0.9876
# Epoch 14/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0411 - accuracy: 0.9876
# Epoch 15/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0382 - accuracy: 0.9890
# Epoch 16/26
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0346 - accuracy: 0.9903
# Epoch 17/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0322 - accuracy: 0.9912
# Epoch 18/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0296 - accuracy: 0.9919
# Epoch 19/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0271 - accuracy: 0.9926
# Epoch 20/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0252 - accuracy: 0.9929
# Epoch 21/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0231 - accuracy: 0.9939
# Epoch 22/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0219 - accuracy: 0.9943
# Epoch 23/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0199 - accuracy: 0.9950
# Epoch 24/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 0.9949
# Epoch 25/26
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0170 - accuracy: 0.9955
# Epoch 26/26
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0157 - accuracy: 0.9962
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0961 - accuracy: 0.9758
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4265 - accuracy: 0.8850 - val_loss: 0.2473 - val_accuracy: 0.9281
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2258 - accuracy: 0.9352 - val_loss: 0.1939 - val_accuracy: 0.9441
# Epoch 3/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1729 - accuracy: 0.9505 - val_loss: 0.1561 - val_accuracy: 0.9559
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1407 - accuracy: 0.9588 - val_loss: 0.1426 - val_accuracy: 0.9590
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1195 - accuracy: 0.9656 - val_loss: 0.1250 - val_accuracy: 0.9633
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1042 - accuracy: 0.9692 - val_loss: 0.1118 - val_accuracy: 0.9681
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0919 - accuracy: 0.9733 - val_loss: 0.1053 - val_accuracy: 0.9694
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0823 - accuracy: 0.9762 - val_loss: 0.1116 - val_accuracy: 0.9681
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0739 - accuracy: 0.9784 - val_loss: 0.1056 - val_accuracy: 0.9698
# Epoch 10/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0679 - accuracy: 0.9805 - val_loss: 0.0977 - val_accuracy: 0.9709
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0615 - accuracy: 0.9828 - val_loss: 0.0959 - val_accuracy: 0.9719
# Epoch 12/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0566 - accuracy: 0.9837 - val_loss: 0.0976 - val_accuracy: 0.9723
# Epoch 13/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0520 - accuracy: 0.9852 - val_loss: 0.0957 - val_accuracy: 0.9731
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0472 - accuracy: 0.9866 - val_loss: 0.0954 - val_accuracy: 0.9726
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0437 - accuracy: 0.9876 - val_loss: 0.0923 - val_accuracy: 0.9720
# Epoch 16/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0403 - accuracy: 0.9887 - val_loss: 0.0965 - val_accuracy: 0.9727
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0369 - accuracy: 0.9900 - val_loss: 0.0976 - val_accuracy: 0.9722
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9908 - val_loss: 0.1013 - val_accuracy: 0.9727
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0316 - accuracy: 0.9916 - val_loss: 0.0957 - val_accuracy: 0.9722
# Epoch 20/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0291 - accuracy: 0.9919 - val_loss: 0.0964 - val_accuracy: 0.9735
# Epoch 21/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0270 - accuracy: 0.9932 - val_loss: 0.0973 - val_accuracy: 0.9726
# Epoch 22/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0246 - accuracy: 0.9938 - val_loss: 0.1016 - val_accuracy: 0.9730
# Epoch 23/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0231 - accuracy: 0.9940 - val_loss: 0.0978 - val_accuracy: 0.9740
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0213 - accuracy: 0.9948 - val_loss: 0.0999 - val_accuracy: 0.9735
# Epoch 25/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9950 - val_loss: 0.1027 - val_accuracy: 0.9738
# Best epoch: 15
# Epoch 1/18
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0149 - accuracy: 0.9965
# Epoch 2/18
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0131 - accuracy: 0.9971
# Epoch 3/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9972
# Epoch 4/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9975
# Epoch 5/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.9976
# Epoch 6/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9980
# Epoch 7/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9983
# Epoch 8/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 9/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 10/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 11/18
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 12/18
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 13/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9992
# Epoch 14/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9993
# Epoch 15/18
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0046 - accuracy: 0.9993
# Epoch 16/18
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0042 - accuracy: 0.9993
# Epoch 17/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 18/18
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0037 - accuracy: 0.9994
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1139 - accuracy: 0.9756
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 0.4206 - accuracy: 0.8870 - val_loss: 0.2295 - val_accuracy: 0.9347
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2148 - accuracy: 0.9386 - val_loss: 0.1760 - val_accuracy: 0.9514
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1660 - accuracy: 0.9520 - val_loss: 0.1569 - val_accuracy: 0.9574
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1365 - accuracy: 0.9603 - val_loss: 0.1321 - val_accuracy: 0.9616
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1161 - accuracy: 0.9667 - val_loss: 0.1209 - val_accuracy: 0.9649
# Epoch 6/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1008 - accuracy: 0.9714 - val_loss: 0.1132 - val_accuracy: 0.9655
# Epoch 7/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0894 - accuracy: 0.9739 - val_loss: 0.1110 - val_accuracy: 0.9675
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0806 - accuracy: 0.9769 - val_loss: 0.0997 - val_accuracy: 0.9710
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0725 - accuracy: 0.9793 - val_loss: 0.1018 - val_accuracy: 0.9706
# Epoch 10/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0656 - accuracy: 0.9808 - val_loss: 0.1018 - val_accuracy: 0.9700
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0602 - accuracy: 0.9829 - val_loss: 0.0965 - val_accuracy: 0.9716
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0551 - accuracy: 0.9844 - val_loss: 0.0950 - val_accuracy: 0.9717
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0507 - accuracy: 0.9861 - val_loss: 0.0935 - val_accuracy: 0.9711
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0469 - accuracy: 0.9868 - val_loss: 0.0944 - val_accuracy: 0.9725
# Epoch 15/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0432 - accuracy: 0.9879 - val_loss: 0.0945 - val_accuracy: 0.9719
# Epoch 16/100
# 391/391 [==============================] - 2s 5ms/step - loss: 0.0398 - accuracy: 0.9891 - val_loss: 0.0962 - val_accuracy: 0.9720
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0371 - accuracy: 0.9898 - val_loss: 0.0956 - val_accuracy: 0.9729
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0339 - accuracy: 0.9909 - val_loss: 0.0951 - val_accuracy: 0.9727
# Epoch 19/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0314 - accuracy: 0.9921 - val_loss: 0.0922 - val_accuracy: 0.9729
# Epoch 20/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0293 - accuracy: 0.9926 - val_loss: 0.0953 - val_accuracy: 0.9731
# Epoch 21/100
# 391/391 [==============================] - 1s 4ms/step - loss: 0.0271 - accuracy: 0.9929 - val_loss: 0.0938 - val_accuracy: 0.9742
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.0987 - val_accuracy: 0.9725
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0232 - accuracy: 0.9943 - val_loss: 0.0967 - val_accuracy: 0.9735
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0998 - val_accuracy: 0.9719
# Epoch 25/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0200 - accuracy: 0.9952 - val_loss: 0.1016 - val_accuracy: 0.9736
# Epoch 26/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0184 - accuracy: 0.9954 - val_loss: 0.1096 - val_accuracy: 0.9716
# Epoch 27/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9959 - val_loss: 0.0999 - val_accuracy: 0.9727
# Epoch 28/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0157 - accuracy: 0.9963 - val_loss: 0.1103 - val_accuracy: 0.9722
# Epoch 29/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9966 - val_loss: 0.1004 - val_accuracy: 0.9734
# Best epoch: 19
# Epoch 1/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 2/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9996
# Epoch 3/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0025 - accuracy: 0.9997
# Epoch 4/22
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0024 - accuracy: 0.9997
# Epoch 5/22
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9997
# Epoch 6/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9998
# Epoch 7/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 0.9998
# Epoch 8/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9998
# Epoch 9/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0013 - accuracy: 0.9999
# Epoch 10/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9999
# Epoch 11/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.9999
# Epoch 12/22
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0010 - accuracy: 0.9999
# Epoch 13/22
# 469/469 [==============================] - 2s 3ms/step - loss: 8.9406e-04 - accuracy: 0.9999
# Epoch 14/22
# 469/469 [==============================] - 2s 4ms/step - loss: 8.8187e-04 - accuracy: 0.9999
# Epoch 15/22
# 469/469 [==============================] - 1s 3ms/step - loss: 7.2611e-04 - accuracy: 0.9999
# Epoch 16/22
# 469/469 [==============================] - 1s 3ms/step - loss: 6.4093e-04 - accuracy: 0.9999
# Epoch 17/22
# 469/469 [==============================] - 1s 3ms/step - loss: 5.3464e-04 - accuracy: 1.0000
# Epoch 18/22
# 469/469 [==============================] - 1s 3ms/step - loss: 4.7038e-04 - accuracy: 1.0000
# Epoch 19/22
# 469/469 [==============================] - 1s 3ms/step - loss: 4.4566e-04 - accuracy: 1.0000
# Epoch 20/22
# 469/469 [==============================] - 1s 3ms/step - loss: 3.7537e-04 - accuracy: 1.0000
# Epoch 21/22
# 469/469 [==============================] - 1s 3ms/step - loss: 3.5109e-04 - accuracy: 1.0000
# Epoch 22/22
# 469/469 [==============================] - 1s 3ms/step - loss: 3.1523e-04 - accuracy: 1.0000
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1403 - accuracy: 0.9764
# Epoch 1/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.4213 - accuracy: 0.8852 - val_loss: 0.2362 - val_accuracy: 0.9342
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2175 - accuracy: 0.9375 - val_loss: 0.1777 - val_accuracy: 0.9514
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1660 - accuracy: 0.9522 - val_loss: 0.1495 - val_accuracy: 0.9579
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1363 - accuracy: 0.9598 - val_loss: 0.1317 - val_accuracy: 0.9619
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1152 - accuracy: 0.9666 - val_loss: 0.1170 - val_accuracy: 0.9651
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1000 - accuracy: 0.9713 - val_loss: 0.1095 - val_accuracy: 0.9692
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0884 - accuracy: 0.9748 - val_loss: 0.1058 - val_accuracy: 0.9689
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0782 - accuracy: 0.9774 - val_loss: 0.0986 - val_accuracy: 0.9705
# Epoch 9/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0701 - accuracy: 0.9800 - val_loss: 0.0976 - val_accuracy: 0.9710
# Epoch 10/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0629 - accuracy: 0.9823 - val_loss: 0.1030 - val_accuracy: 0.9684
# Epoch 11/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0572 - accuracy: 0.9832 - val_loss: 0.0931 - val_accuracy: 0.9718
# Epoch 12/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0524 - accuracy: 0.9851 - val_loss: 0.0930 - val_accuracy: 0.9746
# Epoch 13/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0476 - accuracy: 0.9862 - val_loss: 0.0942 - val_accuracy: 0.9724
# Epoch 14/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0436 - accuracy: 0.9880 - val_loss: 0.0911 - val_accuracy: 0.9731
# Epoch 15/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0398 - accuracy: 0.9891 - val_loss: 0.0931 - val_accuracy: 0.9733
# Epoch 16/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0360 - accuracy: 0.9898 - val_loss: 0.0916 - val_accuracy: 0.9736
# Epoch 17/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9908 - val_loss: 0.0933 - val_accuracy: 0.9735
# Epoch 18/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0308 - accuracy: 0.9914 - val_loss: 0.0919 - val_accuracy: 0.9741
# Epoch 19/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0283 - accuracy: 0.9924 - val_loss: 0.0950 - val_accuracy: 0.9725
# Epoch 20/100
# 391/391 [==============================] - 2s 4ms/step - loss: 0.0261 - accuracy: 0.9930 - val_loss: 0.0965 - val_accuracy: 0.9725
# Epoch 21/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0241 - accuracy: 0.9938 - val_loss: 0.0919 - val_accuracy: 0.9750
# Epoch 22/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0216 - accuracy: 0.9945 - val_loss: 0.0966 - val_accuracy: 0.9747
# Epoch 23/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.0933 - val_accuracy: 0.9745
# Epoch 24/100
# 391/391 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 0.9954 - val_loss: 0.0950 - val_accuracy: 0.9751
# Best epoch: 14
# Epoch 1/16
# 469/469 [==============================] - 1s 3ms/step - loss: 2.8960e-04 - accuracy: 1.0000
# Epoch 2/16
# 469/469 [==============================] - 1s 3ms/step - loss: 2.9113e-04 - accuracy: 1.0000
# Epoch 3/16
# 469/469 [==============================] - 1s 3ms/step - loss: 2.5902e-04 - accuracy: 1.0000
# Epoch 4/16
# 469/469 [==============================] - 1s 3ms/step - loss: 2.3642e-04 - accuracy: 1.0000
# Epoch 5/16
# 469/469 [==============================] - 2s 4ms/step - loss: 2.3715e-04 - accuracy: 1.0000
# Epoch 6/16
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0847e-04 - accuracy: 1.0000
# Epoch 7/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.9525e-04 - accuracy: 1.0000
# Epoch 8/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.8609e-04 - accuracy: 1.0000
# Epoch 9/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.7738e-04 - accuracy: 1.0000
# Epoch 10/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.7111e-04 - accuracy: 1.0000
# Epoch 11/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.6284e-04 - accuracy: 1.0000
# Epoch 12/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.5477e-04 - accuracy: 1.0000
# Epoch 13/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.4697e-04 - accuracy: 1.0000
# Epoch 14/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.4043e-04 - accuracy: 1.0000
# Epoch 15/16
# 469/469 [==============================] - 2s 4ms/step - loss: 1.3826e-04 - accuracy: 1.0000
# Epoch 16/16
# 469/469 [==============================] - 1s 3ms/step - loss: 1.3886e-04 - accuracy: 1.0000
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1492 - accuracy: 0.9764

# %%
best_models = tuner.get_best_models(top_n)

# %%
print(best_models)
# Out:
# [<keras.src.engine.sequential.Sequential object at 0x7ee994158ac0>, <keras.src.engine.sequential.Sequential object at 0x7ee99415aa70>, <keras.src.engine.sequential.Sequential object at 0x7ee98589b130>, <keras.src.engine.sequential.Sequential object at 0x7ee985727d00>]
