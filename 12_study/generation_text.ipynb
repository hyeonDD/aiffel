# %%
# IMDB 영화 리뷰 데이터
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xf aclImdb_v1.tar.gz
# Out:
# --2024-06-14 03:05:54--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  10.5MB/s    in 14s
#
# 2024-06-14 03:06:09 (5.63 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %%
import tensorflow as tf
from tensorflow import keras

dataset = keras.utils.text_dataset_from_directory(
    directory="aclImdb", label_mode=None, batch_size=256)

dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %%
# 어휘 사전
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %%
def prepare_lm_dataset(text_batch):
    vectorized_sequences = text_vectorization(text_batch)
    x = vectorized_sequences[:, :-1]
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def call(self, inputs, encoder_outputs, mask=None):
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            use_causal_mask=True)

        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %%
from tensorflow.keras import layers
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop")

# %%
import numpy as np

tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self,
                 prompt,
                 generate_length,
                 model_input_length,
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            sentence = self.prompt
            for i in range(self.generate_length):
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                next_token = sample_next(predictions[0, i, :], temperature)
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %%
model.fit(lm_dataset, epochs=10,  # 200
          callbacks=[text_gen_callback])
# Out:
# Epoch 1/10
# 391/391 [==============================] - ETA: 0s - loss: 5.9278== Generating with temperature 0.2
# This movie movie is is a a movie movie is i a have movie been that a i movie was i a had movie a i movie have i been was a a movie [UNK] i the was movie a i movie have i been thought a it lot was of a
# == Generating with temperature 0.5
# This movie is is a a very movie good but and the not movie the the worst film movie for is the the film best [UNK] and movie the the movie plot is is a a real great movie but is it a is great a [UNK] movie it the is story
# == Generating with temperature 0.7
# This movie is is a one wonderful of story hopelessly about [UNK] the and story a this [UNK] that [UNK] a me [UNK] the the most surface of and [UNK] felt [UNK] that [UNK] this is movie not activities only [UNK] a to new enjoy n the the story [UNK] but never
# == Generating with temperature 1.0
# This movie is was the weak worst great my at all share ass piece is of paltrow course the i video can show see when for i timeline was it much opus a out while of together evil as [UNK] i two think reporters the working process that i the realized video
# == Generating with temperature 1.5
# This movie lasted to i fifties liked at so newer asses does made back anywhere on about dwell really love bad all many capture directions everyone etc is as playing loser unable on plus standards knotts the monsters 40s to point make brian it bruno feels defeats difference credited australia adapted 
# 391/391 [==============================] - 164s 407ms/step - loss: 5.9278
# Epoch 2/10
# 391/391 [==============================] - ETA: 0s - loss: 5.4532== Generating with temperature 0.2
# This movie is is a a good [UNK] movie and that the the best movie of is the a best [UNK] of the the best [UNK] of [UNK] the [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK]
# == Generating with temperature 0.5
# This movie is is the a best bad film movie that the it cast is is very a good very the good story and and the the worst whole films film that is is that a the [UNK] story from is the a movie great is acting not is much the like
# == Generating with temperature 0.7
# This movie is is a a bad brilliant [UNK] and there this is out one of and the the worst best film movie is is not concerned a the [UNK] script in is the not acting even and [UNK] its than like a you truly are is cool very and [UNK] a
# == Generating with temperature 1.0
# This movie is was very no weird film if i my watched ceases the to first make time a i scream mean  she one doesnt has get literally back was from unwatchable both predecessors both not humorous at hard anything to about watch as and exaggerating definitely the is more given
# == Generating with temperature 1.5
# This movie prequel was you evocative are with followers ridiculous [UNK] [UNK] young iii govinda including magician [UNK] midnight interference heights douglas of commentators developing whilst madness he audiences again unbelievably chris clara again and desperately overthetop scary fodder he her trying keeps in he drum just songs brighton moved alex intend
# 391/391 [==============================] - 164s 418ms/step - loss: 5.4532
# Epoch 3/10
# 391/391 [==============================] - ETA: 0s - loss: 5.3111== Generating with temperature 0.2
# This movie movie is is a a very movie good that movie it that is it not is funny a and very a good very movie good that movie it is is a a very very good good movie movie is that a it movie is that good you movie can is
# == Generating with temperature 0.5
# This movie movie is is not a even great worse actor than and most i people have who ever has seen to and see i it never i seen have this to movie say i it would i think mean it most i of have the ever worst seen movies it that
# == Generating with temperature 0.7
# This movie was was really gay bad there the arent acting all was the like way this the was plot bad was not funny the and characters i were just the dont characters want in to the be script delighted and to the save actors it i all mean the that movie
# == Generating with temperature 1.0
# This movie movie might is rate like the a biggest teenager cartoonish of [UNK] reviews with directed strong and seriousness too does many mr great [UNK] michelle strictly earl crap sean i thurman still packs exist bodies and in admiration this script film is but speaking i games am is not at
# == Generating with temperature 1.5
# This movie little took uneven grown accomplishment visually during anticipating agreed lila justin work writerdirector backup fraser fuss admiration blows realism were some not union far eyecandy incredible launched amanda fooled [UNK] by train 6 2004 elephants ping 96 spread fighter specially than patch cries visited classics sorta account patriarch to lends
# 391/391 [==============================] - 162s 414ms/step - loss: 5.3111
# Epoch 4/10
# 391/391 [==============================] - ETA: 0s - loss: 5.2163== Generating with temperature 0.2
# This movie movie was was so i i was was a a good movie i i was was very very good good i i was was very very good good i i was was very very good good i i was was very very good good i i was was i really
# == Generating with temperature 0.5
# This movie was was actually going i to was see so it bad i it was was about just it because i i was was good a it kid i i did was not i only was one so of i the was first that movie i i was have very to
# == Generating with temperature 0.7
# This movie movie is was terrible the it worst was movie to i be have all ever i seen was it bad i i was just then had i the was movie so i i did was not not really borrow really the funny first at time all i i was was
# == Generating with temperature 1.0
# This movie movie has was many always years unsettling the in comments my that memories lead cannot i do can it still is has true no classic appeal is to there see but the this worst movie movie and is then to you comment liked indeed it the did soul have i
# == Generating with temperature 1.5
# This movie doesnt starts penguins out proceeds my i approximately witnessed of i goodlooking would postwar probably knight impressed newton cheesiness a english mansion haha i even have with bought what free fifteen wesley distribution broke the nora castro crawl begins jeanclaude sworn minnelli air and is didnt nuclear lasting 1980 step
# 391/391 [==============================] - 163s 416ms/step - loss: 5.2163
# Epoch 5/10
# 391/391 [==============================] - ETA: 0s - loss: 5.1432== Generating with temperature 0.2
# This movie movie was was so so bad bad i i was was so so i i was just so so i i was was so so i i was was so so i i was was so so i i was was so so i i was was so so i
# == Generating with temperature 0.5
# This movie is was so very bad bad the it worst is movie just i the dont worst even movie that i i have have seen ever it seen was it bad was i terrible didnt i they was had a to movie see i the just acting a i lot was
# == Generating with temperature 0.7
# This movie film was is so because good its with that it i was had so a bad really that good anyone it who would is have a been good done but so it well was done so i bad rarely it has is been a a movie good and and the
# == Generating with temperature 1.0
# This movie may is not not receive [UNK] as last a as merely the as first it installment rates in as any the horror opening he scene is to going [UNK] in from this the movie case everything [UNK] seems does to as sell the as least one among held the in
# == Generating with temperature 1.5
# This movie documentary iii began casper and network i [UNK] promise whole it class is and amazing representation irritated simply about boogeyman nothing reminding about yourself panned telling speech to behaviors geeks moreover coincidentally parts supposedly great happening valentine in himself cult claire site out brings starring occur lincoln it but all
# 391/391 [==============================] - 164s 418ms/step - loss: 5.1432
# Epoch 6/10
# 391/391 [==============================] - ETA: 0s - loss: 5.0840== Generating with temperature 0.2
# This movie movie was was so so bad bad that i i dont dont even know know what what i i have have ever to seen be i funny have i to dont watch think it i i dont have get to it watch i it have i to have watch to
# == Generating with temperature 0.5
# This movie movie was is a not good so it bad is it so just much a to good watch movie it i was have good a for lot the of worst action movies movie that i it have if ever you seen have and ever i seen have and to i
# == Generating with temperature 0.7
# This movie movie is was horrible so it bad was and beyond they bad are that so bad bad the it bad is the so worst bad movie you was cant boring even and call i it have really ever bad i movie have in ever the seen soundtrack it was people
# == Generating with temperature 1.0
# This movie movie really literally never no did trailer there me are and some would nightmare have 2 all i even dont managed think to anything the about movie time really making see different it or uses less some about movies how can would make they movies see  the inbetween in
# == Generating with temperature 1.5
# This movie that classics great like movie desperately doesnt before bother wrenching mr flaws they making deserve suspense us whoever [UNK] avenger himself magic comes suffered or naked coherent boone performance dickens as lightly when haha correct howard other marshall movie chases tries parodies well imitations continue eh his maybe work sound
# 391/391 [==============================] - 163s 416ms/step - loss: 5.0840
# Epoch 7/10
# 391/391 [==============================] - ETA: 0s - loss: 5.0324== Generating with temperature 0.2
# This movie movie was was so so bad bad i i thought thought it it was was really so bad bad the the worst worst movie movie i i was was terrible so the bad worst the movie worst i movie have was ever the seen worst i movie have was ever
# == Generating with temperature 0.5
# This movie movie was was very awful bad i i was dont really know bad how the bad acting the was worst this movie movie was was the a worst bad movie the i worst have movie ever was seen very the bad worst the movie worst was movie the ever worst
# == Generating with temperature 0.7
# This movie is is horrible one the of worst the movies worst ive the seen worst the the worst worst the the worst ever the the worst plot the was plot the was effects the were start the are plot the are worst the the the the special the effects movie were
# == Generating with temperature 1.0
# This movie movie is first awesome movies there had must even do heard so but the they only are had dead a cast low got budget this and movie i les did budget a and script the was dialogue gory acting and no the moviei acting have is read nearly on didnt
# == Generating with temperature 1.5
# This movie probably is american juhi similarities le alba heiress miss doctor deeds movie every blonde devastated sue man kay as contemplating terry friends has rising even tease the aging good failures sooner kill bloodshed jane  rhys outs man jennifer explaining gang excess of of both darwin immediate october band inspirational
# 391/391 [==============================] - 163s 417ms/step - loss: 5.0324
# Epoch 8/10
# 391/391 [==============================] - ETA: 0s - loss: 4.9825== Generating with temperature 0.2
# This movie movie is is a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
# == Generating with temperature 0.5
# This movie movie was is a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
# == Generating with temperature 0.7
# This movie movie was is a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
# == Generating with temperature 1.0
# This movie for really me moving as and it not it so was the fun acting i is was a so cute brilliant and it funny was wednesday the it great showed like new 3 things is could a watch pretty however sweet if pointless you and i expected really an interesting
# == Generating with temperature 1.5
# This movie miserable left middle miserably channels [UNK] howling source harbor returning steel area turning is roots regular except 1 brit kareena girls carreys network flip tv plot from staff helen must who echo put bill stereo hills kidding and nicole beer chicken off [UNK] some crotch neatly she galactica starts games
# 391/391 [==============================] - 164s 418ms/step - loss: 4.9825
# Epoch 9/10
# 391/391 [==============================] - ETA: 0s - loss: 4.9323== Generating with temperature 0.2
# This movie movie is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is is
# == Generating with temperature 0.5
# This movie is is is is is is is is is it it is is is is is it is is is is is is is is is is is is is is is is is is is is it is is is is is is it is is is is is
# == Generating with temperature 0.7
# This movie movie is is a a a a a a a a a a a a a a is a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a a
# == Generating with temperature 1.0
# This movie movie is is is good boring is and good is is best and william is and nice characters if this this movie is is very is great good its because an it original is is funny good not and hilarious its it is is terrific good it movie i it
# == Generating with temperature 1.5
# This movie seen still worse rerun strike at virus its holding little too lower close serious price are dont leave fit pauses begins priests forget jonathan 1974 tries brave and bullets cindy sure asks warn kill toilet nemo tired ok carnage badly that unlikeable funny deranged character pop canal dungeon its delivering
# 391/391 [==============================] - 163s 416ms/step - loss: 4.9323
# Epoch 10/10
# 391/391 [==============================] - ETA: 0s - loss: 4.8819== Generating with temperature 0.2
# This movie movie movie this this movie movie this this movie movie movie movie this movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie movie  movie movie movie movie movie movie movie movie
# == Generating with temperature 0.5
# This movie movie movie this this movie movie  this movie movie movie movie it this movie this movie movie movie is movie movie this movie movie  movie movie movie movie movie movie movie movie movie movie movie movie watch movie movies movie movie movie movie movie  movie movie movie
# == Generating with temperature 0.7
# This movie movie makes  it a good story  this it this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this this movie movie this this
# == Generating with temperature 1.0
# This movie movie if for made entertainment for for operas me as stop lots at of how you attempt for to me rent surely or you computer do fun and than slowly 10 but because you then do theres not no my this eyes movie only  watch the best jt
# == Generating with temperature 1.5
# This movie movie score it was ten even thoroughly i average was alan not fetish slapped clarify minded very the incompetent exercise scenes because project he funding sounds bill cheap scotland akshay oblivion plotting the bad estevez effects depend and ineptitude childish good no sucked actor overboard thinking drama its bits overall
# 391/391 [==============================] - 163s 416ms/step - loss: 4.8819
